# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# %%
## Storing all the files into dataframes

sample = pd.read_csv('sample_submission.csv')
categories = pd.read_csv('item_categories.csv')
items = pd.read_csv('items.csv')
shops = pd.read_csv('shops.csv')
sales_train = pd.read_csv('sales_train.csv')
sales_test = pd.read_csv('test.csv')

# %%
sales_test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
sales_train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
## Joining training data to the different item names
new_train = sales_train.join(items.set_index('item_id'),on='item_id')

# %%
## Joining training data to the different item catagories
new_train = new_train.join(categories.set_index('item_category_id'),on='item_category_id')

# %%
new_train = new_train.join(shops.set_index('shop_id'),on='shop_id')

# %%
sns.lineplot(data=new_train,x='date',y=)
# Out:
#   File "<ipython-input-36-e2c26dc93a62>", line 1
#     sns.lineplot(data=new_train,x='date',y=)
#                                            ^
# SyntaxError: invalid syntax

# %%
new_train['item_price'].nunique()

# %%
new_train['item_name'].nunique()

# %%
## Need to figure out how to extract total sales by date

## This gives us total sales by shop
new_train.groupby('shop_name').sum()

# %%
new_train.groupby('date')

# %%
## Looking to see how many rows we have
new_train.shape

# %%
## Looking for outliers 
new_new = new_train[new_train['item_price']<=5000]

# %%
## Looking at the shape of the item prices without 
new_new['item_price'].hist()

# %%
outliers = new_train[new_train['item_price']>=5000]

# %%
outliers

# %%
33831/2935849
# Out:
# 0.011523412818574797

# %%
train_prepped = new_train[new_train['item_price']<=5000]

# %%
train_prepped
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 1                 1.0           DEEP PURPLE  The House Of Blue Light  LP
# 2                -1.0           DEEP PURPLE  The House Of Blue Light  LP
# 3                 1.0           DEEP PURPLE  Who Do You Think We Are  LP
# 4                 1.0            DEEP PURPLE 30 Very Best Of 2CD (Фирм.)
# ...               ...                                                ...
# 2935844           1.0                   V/A Nu Jazz Selection (digipack)
# 2935845           1.0             V/A The Golden Jazz Collection  1  2CD
# 2935846           1.0                       V/A The Best Of The 3 Tenors
# 2935847           1.0  V/A Relax Collection  Planet MP3 (mp3-CD) (jewel)
# 2935848           1.0             V/A The Golden Jazz Collection  1  2CD
#
#          item_category_id                   item_category_name  \
# 0                      37                       Кино - Blu-Ray
# 1                      58                       Музыка - Винил
# 2                      58                       Музыка - Винил
# 3                      58                       Музыка - Винил
# 4                      56  Музыка - CD фирменного производства
# ...                   ...                                  ...
# 2935844                55  Музыка - CD локального производства
# 2935845                55  Музыка - CD локального производства
# 2935846                55  Музыка - CD локального производства
# 2935847                57                         Музыка - MP3
# 2935848                55  Музыка - CD локального производства
#
#                       shop_name
# 0        Ярославль ТЦ "Альтаир"
# 1           Москва ТРК "Атриум"
# 2           Москва ТРК "Атриум"
# 3           Москва ТРК "Атриум"
# 4           Москва ТРК "Атриум"
# ...                         ...
# 2935844     Москва ТРК "Атриум"
# 2935845     Москва ТРК "Атриум"
# 2935846     Москва ТРК "Атриум"
# 2935847     Москва ТРК "Атриум"
# 2935848     Москва ТРК "Атриум"
#
# [2902039 rows x 10 columns]

# %%
## Attempts at seeing if it clusters

print(test_prepped['shop_id'].nunique())
print('\b')
print(test_prepped['date_block_num'].nunique())

print(60*34)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-dd13ce18a135> in <module>
#       1 ## Attempts at seeing if it clusters
#       2
# ----> 3 print(test_prepped['shop_id'].nunique())
#       4 print('\b')
#       5 print(test_prepped['date_block_num'].nunique())
#
# NameError: name 'test_prepped' is not defined

# %%
train_prepped['date_time'] = pd.to_datetime(train_prepped['date'],format='%d.%m.%Y')
train_prepped
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 1                 1.0           DEEP PURPLE  The House Of Blue Light  LP
# 2                -1.0           DEEP PURPLE  The House Of Blue Light  LP
# 3                 1.0           DEEP PURPLE  Who Do You Think We Are  LP
# 4                 1.0            DEEP PURPLE 30 Very Best Of 2CD (Фирм.)
# ...               ...                                                ...
# 2935844           1.0                   V/A Nu Jazz Selection (digipack)
# 2935845           1.0             V/A The Golden Jazz Collection  1  2CD
# 2935846           1.0                       V/A The Best Of The 3 Tenors
# 2935847           1.0  V/A Relax Collection  Planet MP3 (mp3-CD) (jewel)
# 2935848           1.0             V/A The Golden Jazz Collection  1  2CD
#
#          item_category_id                   item_category_name  \
# 0                      37                       Кино - Blu-Ray
# 1                      58                       Музыка - Винил
# 2                      58                       Музыка - Винил
# 3                      58                       Музыка - Винил
# 4                      56  Музыка - CD фирменного производства
# ...                   ...                                  ...
# 2935844                55  Музыка - CD локального производства
# 2935845                55  Музыка - CD локального производства
# 2935846                55  Музыка - CD локального производства
# 2935847                57                         Музыка - MP3
# 2935848                55  Музыка - CD локального производства
#
#                       shop_name  date_time
# 0        Ярославль ТЦ "Альтаир" 2013-01-02
# 1           Москва ТРК "Атриум" 2013-01-03
# 2           Москва ТРК "Атриум" 2013-01-05
# 3           Москва ТРК "Атриум" 2013-01-06
# 4           Москва ТРК "Атриум" 2013-01-15
# ...                         ...        ...
# 2935844     Москва ТРК "Атриум" 2015-10-10
# 2935845     Москва ТРК "Атриум" 2015-10-09
# 2935846     Москва ТРК "Атриум" 2015-10-14
# 2935847     Москва ТРК "Атриум" 2015-10-22
# 2935848     Москва ТРК "Атриум" 2015-10-03
#
# [2902039 rows x 11 columns]

# %%
df= train_prepped.groupby(['shop_id','date_block_num'],as_index=False)['item_cnt_day'].sum()
df
# Out:
#       shop_id  date_block_num  item_cnt_day
# 0           0               0        5533.0
# 1           0               1        6066.0
# 2           1               0        2922.0
# 3           1               1        3334.0
# 4           2               0        1124.0
# ...       ...             ...           ...
# 1580       59              29         905.0
# 1581       59              30         984.0
# 1582       59              31        1209.0
# 1583       59              32         899.0
# 1584       59              33         766.0
#
# [1585 rows x 3 columns]

# %%
df= train_prepped.groupby(['date_block_num','shop_id'],as_index=False)['item_cnt_day'].sum()
df
# Out:
#       date_block_num  shop_id  item_cnt_day
# 0                  0        0        5533.0
# 1                  0        1        2922.0
# 2                  0        2        1124.0
# 3                  0        3         762.0
# 4                  0        4        2096.0
# ...              ...      ...           ...
# 1580              33       55        1965.0
# 1581              33       56        1248.0
# 1582              33       57        2275.0
# 1583              33       58        1423.0
# 1584              33       59         766.0
#
# [1585 rows x 3 columns]

# %%
## Graphing Monthly Sales number by company
plt.figure(figsize=[10,18])

sns.lineplot(data=df,x='date_block_num',y='item_cnt_day',hue='shop_id',palette='dark')
plt.legend(bbox_to_anchor=(1.2,1))

# %%
monthly_sales=train_prepped.groupby(["date_block_num","shop_id","item_id"])[
    "date_time","item_price","item_cnt_day"].agg({"date_time":["min",'max'],"item_price":"mean","item_cnt_day":"sum"})
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
df
# Out:
#       date_block_num  shop_id  item_cnt_day
# 0                  0        0        5533.0
# 1                  0        1        2922.0
# 2                  0        2        1124.0
# 3                  0        3         762.0
# 4                  0        4        2096.0
# ...              ...      ...           ...
# 1580              33       55        1965.0
# 1581              33       56        1248.0
# 1582              33       57        2275.0
# 1583              33       58        1423.0
# 1584              33       59         766.0
#
# [1585 rows x 3 columns]

# %%
monthly_sales.head()
# Out:
#                                 date_time            item_price item_cnt_day
#                                       min        max       mean          sum
# date_block_num shop_id item_id
# 0              0       32      2013-01-03 2013-01-31      221.0          6.0
#                        33      2013-01-03 2013-01-28      347.0          3.0
#                        35      2013-01-31 2013-01-31      247.0          1.0
#                        43      2013-01-31 2013-01-31      221.0          1.0
#                        51      2013-01-13 2013-01-31      128.5          2.0

# %%
grouped = pd.DataFrame(train_prepped.groupby(['shop_id', 'date_block_num'])['item_cnt_day'].sum().reset_index())
fig, axes = plt.subplots(nrows=5, ncols=2, sharex=True, sharey=True, figsize=(16,20))
num_graph = 10
id_per_graph = ceil(grouped.shop_id.max() / num_graph)
count = 0
for i in range(5):
    for j in range(2):
        sns.pointplot(x='date_block_num', y='item_cnt_day', hue='shop_id', data=grouped[np.logical_and(count*id_per_graph <= grouped['shop_id'], grouped['shop_id'] < (count+1)*id_per_graph)], ax=axes[i][j])
        count += 1

# %%
len(train_prepped)
# Out:
# 2902039

# %%
len(sales_test)
# Out:
# 214200

# %%
2902039/214200
# Out:
# 13.548267973856209

# %%
sales_test['item_id'].nunique()
# Out:
# 5100

# %%
train_prepped['item_id'].nunique()
# Out:
# 21500

# %%
sales_test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
train_prepped
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 1                 1.0           DEEP PURPLE  The House Of Blue Light  LP
# 2                -1.0           DEEP PURPLE  The House Of Blue Light  LP
# 3                 1.0           DEEP PURPLE  Who Do You Think We Are  LP
# 4                 1.0            DEEP PURPLE 30 Very Best Of 2CD (Фирм.)
# ...               ...                                                ...
# 2935844           1.0                   V/A Nu Jazz Selection (digipack)
# 2935845           1.0             V/A The Golden Jazz Collection  1  2CD
# 2935846           1.0                       V/A The Best Of The 3 Tenors
# 2935847           1.0  V/A Relax Collection  Planet MP3 (mp3-CD) (jewel)
# 2935848           1.0             V/A The Golden Jazz Collection  1  2CD
#
#          item_category_id                   item_category_name  \
# 0                      37                       Кино - Blu-Ray
# 1                      58                       Музыка - Винил
# 2                      58                       Музыка - Винил
# 3                      58                       Музыка - Винил
# 4                      56  Музыка - CD фирменного производства
# ...                   ...                                  ...
# 2935844                55  Музыка - CD локального производства
# 2935845                55  Музыка - CD локального производства
# 2935846                55  Музыка - CD локального производства
# 2935847                57                         Музыка - MP3
# 2935848                55  Музыка - CD локального производства
#
#                       shop_name  date_time
# 0        Ярославль ТЦ "Альтаир" 2013-01-02
# 1           Москва ТРК "Атриум" 2013-01-03
# 2           Москва ТРК "Атриум" 2013-01-05
# 3           Москва ТРК "Атриум" 2013-01-06
# 4           Москва ТРК "Атриум" 2013-01-15
# ...                         ...        ...
# 2935844     Москва ТРК "Атриум" 2015-10-10
# 2935845     Москва ТРК "Атриум" 2015-10-09
# 2935846     Москва ТРК "Атриум" 2015-10-14
# 2935847     Москва ТРК "Атриум" 2015-10-22
# 2935848     Москва ТРК "Атриум" 2015-10-03
#
# [2902039 rows x 11 columns]
